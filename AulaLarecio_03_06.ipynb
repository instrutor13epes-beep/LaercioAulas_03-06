# %% [markdown]
# ## Print():
# O megafone do programa.
#
# Teste o Comando Print:
# Digite abaixo o comando:
#
#
# ```
# print("Olá Mundo")
# ```

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Mais exemplos de print()
#
# ```
# print("Bem-vindo ao sistema!")
# print("O resultado é:" , 42)
# print("Python","é", "incrível")
# ```

# %%
print("Bem-vindo ao sistema!")
print("O resultado é:",42)
print("Python","é","incrível")
# Out:
# Bem-vindo ao sistema!
# O resultado é: 42
# Python é incrível
